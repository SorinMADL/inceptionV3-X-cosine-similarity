# %%
import keras
from keras.models import Model
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def getInceptionV3():
    # get the inception V3 model
    modelInceptionV3 = keras.applications.InceptionV3(weights='imagenet')

    # remove the last layer
    modelInceptionV3OutLayer = modelInceptionV3.layers[len(modelInceptionV3.layers)-2].name
    modelInceptionV3NN =  Model(inputs=modelInceptionV3.input, outputs=modelInceptionV3.get_layer(modelInceptionV3OutLayer).output) 
    return modelInceptionV3NN

# %%
def inference_over_image(path_to_image, modelInceptionV3NN, toPrint=False):
  img_raw = tf.io.read_file(path_to_image)
  img = tf.io.decode_image(img_raw)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = tf.image.resize(img, [299,299])
  img_to_show = img
  img = np.expand_dims(img, 0)
  if toPrint == True:
    _ = plt.imshow(img_to_show)
  return modelInceptionV3NN.predict(img)

# %%
cosine_loss = tf.keras.losses.CosineSimilarity(axis=1)
modelInceptionV3NN = getInceptionV3()

# %%
a1 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/a1.jpg', modelInceptionV3NN, True)
a2 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/a2.jpg', modelInceptionV3NN)
a3 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/a3.jpg', modelInceptionV3NN)
a4 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/a4.jpg', modelInceptionV3NN)

# %%
c1 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/c1.jpg', modelInceptionV3NN, True)
c2 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/c2.jpg', modelInceptionV3NN)
c3 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/c3.jpg', modelInceptionV3NN)
c4 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/c4.jpg', modelInceptionV3NN)

# %%
g1 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/g1.jpg', modelInceptionV3NN, True)
g2 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/g2.jpg', modelInceptionV3NN)
g3 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/g3.jpg', modelInceptionV3NN)
g4 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/g4.jpg', modelInceptionV3NN)

# %%
n1 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/n1.jpg', modelInceptionV3NN, True)
n2 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/n2.jpg', modelInceptionV3NN)
n3 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/n3.jpg', modelInceptionV3NN)
n4 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/n4.jpg', modelInceptionV3NN)

# %%
p1 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/p1.jpg', modelInceptionV3NN, True)
p2 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/p2.jpg', modelInceptionV3NN)
p3 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/p3.jpg', modelInceptionV3NN)
p4 = inference_over_image('/content/drive/My Drive/dl_replace_nn_output_cosine_sim/train:)/p4.jpg', modelInceptionV3NN)

# %%
values = np.array((a1[0], a2[0], a3[0], a4[0], c1[0], c2[0], c3[0], c4[0], g1[0], g2[0], g3[0], g4[0], n1[0], n2[0], n3[0], n4[0], p1[0], p2[0], p3[0], p4[0]))

# %%
np.savetxt("/content/drive/My Drive/dl_replace_nn_output_cosine_sim/data.csv", values, delimiter=",")
